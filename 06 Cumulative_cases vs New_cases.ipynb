# %%
import pandas as pd #Daten
from matplotlib import pyplot as plt # plots
#import matplotlib as mpl
from matplotlib.ticker import FuncFormatter   # Numberformat plot ticks
import numpy as np

# performance
from datetime import datetime
from datetime import date # todays date
#import seaborn as sns

import os
now = datetime.now()
today = date.today().strftime("%d.%m.%Y")

# %%
# Webabruf - CSV einlesen
df = pd.read_csv("https://covid19.who.int/WHO-COVID-19-global-data.csv")

# %%
ger = df[df.Country == 'Germany']
fr = df[df.Country == 'France']
at = df[df.Country == 'Austria']
pl = df[df.Country == 'Poland']
cz = df[df.Country == 'Czechia']
ch = df[df.Country == 'Switzerland']
it = df[df.Country == 'Italy']
es = df[df.Country == 'Spain']
gb = df[df.Country == 'The United Kingdom']

isr = df[df.Country == 'Israel']
se = df[df.Country == 'Sweden']
usa = df[df.Country == 'United States of America']
spa = df[df.Country == 'Spain']
ita = df[df.Country == 'Italy']
rus = df[df.Country == 'Russian Federation']

# %%
ger
# Out:
#       Date_reported Country_code  Country WHO_region  New_cases  \
# 35334    2020-01-03           DE  Germany       EURO          0
# 35335    2020-01-04           DE  Germany       EURO          0
# 35336    2020-01-05           DE  Germany       EURO          0
# 35337    2020-01-06           DE  Germany       EURO          0
# 35338    2020-01-07           DE  Germany       EURO          0
# ...             ...          ...      ...        ...        ...
# 35782    2021-03-26           DE  Germany       EURO      21573
# 35783    2021-03-27           DE  Germany       EURO      20472
# 35784    2021-03-28           DE  Germany       EURO      17176
# 35785    2021-03-29           DE  Germany       EURO       9872
# 35786    2021-03-30           DE  Germany       EURO       9549
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 35334                 0           0                  0
# 35335                 0           0                  0
# 35336                 0           0                  0
# 35337                 0           0                  0
# 35338                 0           0                  0
# ...                 ...         ...                ...
# 35782           2734753         183              75623
# 35783           2755225         157              75780
# 35784           2772401          90              75870
# 35785           2782273          43              75913
# 35786           2791822         180              76093
#
# [453 rows x 8 columns]

# %%
plt.figure(figsize=(16,9))


y = ger["New_cases"].rolling(window=7,min_periods=1).mean()
x = ger["Cumulative_cases"]


plt.plot(x,y)

plt.yscale('log')
plt.xscale('log')

plt.ylabel('Neue Fälle', fontsize = 20)
plt.xlabel('Cases', fontsize=20)

plt.title('Neue Fälle pro Tag - absolute Zahlen (WHO-Daten)\n', fontsize=20)
plt.suptitle(today + ' PW', fontsize=15, y=0.91)


plt.show()
